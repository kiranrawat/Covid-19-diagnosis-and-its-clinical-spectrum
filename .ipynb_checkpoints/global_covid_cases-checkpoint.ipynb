# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Data URLS
config = {}
config['recovered_csv_url'] = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
config['confirmed_csv_url'] = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
config['death_csv_url'] = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'

# %%
recovered_df = pd.read_csv(config['recovered_csv_url'])
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/12/20  7/13/20  7/14/20  \
# 0        0        0        0        0  ...    21216    21254    21454
# 1        0        0        0        0  ...     1946     2014     2062
# 2        0        0        0        0  ...    13743    14019    14295
# 3        0        0        0        0  ...      803      803      803
# 4        0        0        0        0  ...      118      118      118
#
#    7/15/20  7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20
# ...

# %%
confirmed_df = pd.read_csv(config['confirmed_csv_url'])
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/12/20  7/13/20  7/14/20  \
# 0        0        0        0        0  ...    34451    34455    34740
# 1        0        0        0        0  ...     3454     3571     3667
# 2        0        0        0        0  ...    19195    19689    20216
# 3        0        0        0        0  ...      855      858      861
# 4        0        0        0        0  ...      506      525      541
#
#    7/15/20  7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20
# ...

# %%
death_df = pd.read_csv(config['death_csv_url'])
death_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/12/20  7/13/20  7/14/20  \
# 0        0        0        0        0  ...     1010     1012     1048
# 1        0        0        0        0  ...       93       95       97
# 2        0        0        0        0  ...     1011     1018     1028
# 3        0        0        0        0  ...       52       52       52
# 4        0        0        0        0  ...       26       26       26
#
#    7/15/20  7/16/20  7/17/20  7/18/20  7/19/20  7/20/20  7/21/20
# ...

# %%
print("Total globally confirmed cases",confirmed_df.shape)
print("Total globally recovered cases",recovered_df.shape)
print("Total globally deaths",death_df.shape)
# Out:
# Total globally confirmed cases (266, 186)
# Total globally recovered cases (266, 186)
# Total globally deaths (266, 186)

# %%
confirmed_df.columns[4:]
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '7/12/20', '7/13/20', '7/14/20', '7/15/20', '7/16/20', '7/17/20',
#        '7/18/20', '7/19/20', '7/20/20', '7/21/20'],
#       dtype='object', length=182)

# %%
confirmed_df['Province/State'].value_counts()
# Out:
# Gibraltar           1
# St Martin           1
# New South Wales     1
# Hebei               1
# Henan               1
#                    ..
# Tasmania            1
# Anguilla            1
# Diamond Princess    1
# Liaoning            1
# Nova Scotia         1
# Name: Province/State, Length: 81, dtype: int64

# %% [markdown]
# "we have all the columns 'ProProvince/State', 'Country/Region', 'Lat' and 'Long' and 'dates' common in all three dataframes. Each date value is serving as a column name, so, its needed to transform the date columns into rows.

# %%
dates = confirmed_df.columns[4:]

new_confirmed_df = pd.melt(confirmed_df, id_vars =['Province/State', 'Country/Region', 'Lat', 'Long'], value_vars = dates, 
              var_name ='Date', value_name ='Confirmed') 

new_recovered_df = pd.melt(recovered_df, id_vars =['Province/State', 'Country/Region', 'Lat', 'Long'], value_vars = dates, 
              var_name ='Date', value_name ='Recovered')

new_deaths_df = pd.melt(death_df, id_vars =['Province/State', 'Country/Region', 'Lat', 'Long'], value_vars = dates, 
              var_name ='Date', value_name ='Deaths')

# %%
new_confirmed_df
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 48407            NaN  Sao Tome and Principe   0.186400   6.613100  7/21/20
# 48408            NaN                  Yemen  15.552727  48.516388  7/21/20
# 48409            NaN                Comoros -11.645500  43.333300  7/21/20
# 48410            NaN             Tajikistan  38.861000  71.276100  7/21/20
# 48411            NaN                Lesotho -29.610000  28.233600  7/21/20
#
#        Confirmed
# 0              0
# 1              0
# ...

# %%
print("New shape of confirmed df",new_confirmed_df.shape)
print("New shape of recivered df",new_recovered_df.shape)
print("New shape of deaths df ",new_deaths_df.shape)
# Out:
# New shape of confirmed df (48412, 6)
# New shape of recivered df (48412, 6)
# New shape of deaths df  (48412, 6)

# %%
# dummy = new_recovered_df[new_recovered_df['Country/Region'] == 'Canada']

# %%
# plt.figure.Figure(figsize = (30,20))
plt.figure(figsize=(40,20))
sns.lineplot(x="Date", y="Confirmed", data=new_confirmed_df)

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(50, 10))

# Add x-axis and y-axis
ax.bar(new_confirmed_df['Date'],
    new_confirmed_df['Confirmed']
      )

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Confirmed Cases",
       title="Daily Covid-19 Confirmed Cases")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
# 'Canada' in new_recovered_df['Province/State'].to_list()

# %%
# new_recovered_df[new_recovered_df['Country/Region'] == 'Canada'][new_recovered_df['Date'] == '2/25/20']

# %%
# new_recovered_df[new_recovered_df['Country/Region'] == 'United Kingdom']

# %%
new_recovered_df
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 48407            NaN  Sao Tome and Principe   0.186400   6.613100  7/21/20
# 48408            NaN                  Yemen  15.552727  48.516388  7/21/20
# 48409            NaN                Comoros -11.645500  43.333300  7/21/20
# 48410            NaN             Tajikistan  38.861000  71.276100  7/21/20
# 48411            NaN                Lesotho -29.610000  28.233600  7/21/20
#
#        Recovered
# 0              0
# 1              0
# ...

# %%
# new_confirmed_df

# %%
# new_deaths_df

# %%
df_inner = pd.merge(new_recovered_df, new_confirmed_df, on=['Province/State', 'Country/Region','Date', 'Lat', 'Long'], how='inner')

df_inner
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 48407            NaN  Sao Tome and Principe   0.186400   6.613100  7/21/20
# 48408            NaN                  Yemen  15.552727  48.516388  7/21/20
# 48409            NaN                Comoros -11.645500  43.333300  7/21/20
# 48410            NaN             Tajikistan  38.861000  71.276100  7/21/20
# 48411            NaN                Lesotho -29.610000  28.233600  7/21/20
#
#        Recovered  Confirmed
# 0              0          0
# ...

# %%
df_final = pd.merge(df_inner, new_deaths_df, on= ['Province/State', 'Country/Region','Date', 'Lat', 'Long'], how='inner')
df_final
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 48407            NaN  Sao Tome and Principe   0.186400   6.613100  7/21/20
# 48408            NaN                  Yemen  15.552727  48.516388  7/21/20
# 48409            NaN                Comoros -11.645500  43.333300  7/21/20
# 48410            NaN             Tajikistan  38.861000  71.276100  7/21/20
# 48411            NaN                Lesotho -29.610000  28.233600  7/21/20
#
#        Recovered  Confirmed  Deaths
# ...

# %%
# plt.figure.Figure(figsize = (30,20))
ca_data = df_final[df_final['Country/Region']=='United Kingdom']

after_start_date = ca_data["Date"] >= '1/22/20'
before_end_date = ca_data["Date"] <= '3/22/20'
between_two_dates = after_start_date & before_end_date
filtered_ca_data = ca_data.loc[between_two_dates]

plt.figure(figsize=(40,20))
sns.barplot(x="Date", y="Confirmed", data=filtered_ca_data)

# %%
ca_data[ca_data['Date'] == '3/22/20']
# Out:
#                     Province/State  Country/Region        Lat       Long  \
# 16177                      Bermuda  United Kingdom  32.307800 -64.750500
# 16178               Cayman Islands  United Kingdom  19.313300 -81.254600
# 16179              Channel Islands  United Kingdom  49.372300  -2.364400
# 16180                    Gibraltar  United Kingdom  36.140800  -5.353600
# 16181                  Isle of Man  United Kingdom  54.236100  -4.548100
# 16182                   Montserrat  United Kingdom  16.742498 -62.187366
# 16183                          NaN  United Kingdom  55.378100  -3.436000
# 16208                     Anguilla  United Kingdom  18.220600 -63.068600
# 16209       British Virgin Islands  United Kingdom  18.420700 -64.640000
# 16210     Turks and Caicos Islands  United Kingdom  21.694000 -71.797900
# 16217  Falkland Islands (Malvinas)  United Kingdom -51.796300 -59.523600
#
#           Date  Recovered  Confirmed  Deaths
# 16177  3/22/20          6          6       0
# ...

# %%
new_confirmed_df[new_confirmed_df['Date'] == '3/22/20']
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 15960            NaN            Afghanistan  33.939110  67.709953  3/22/20
# 15961            NaN                Albania  41.153300  20.168300  3/22/20
# 15962            NaN                Algeria  28.033900   1.659600  3/22/20
# 15963            NaN                Andorra  42.506300   1.521800  3/22/20
# 15964            NaN                 Angola -11.202700  17.873900  3/22/20
# ...              ...                    ...        ...        ...      ...
# 16221            NaN  Sao Tome and Principe   0.186400   6.613100  3/22/20
# 16222            NaN                  Yemen  15.552727  48.516388  3/22/20
# 16223            NaN                Comoros -11.645500  43.333300  3/22/20
# 16224            NaN             Tajikistan  38.861000  71.276100  3/22/20
# 16225            NaN                Lesotho -29.610000  28.233600  3/22/20
#
#        Confirmed
# 15960         40
# 15961         89
# ...

# %%
new_recovered_df[new_recovered_df['Date'] == '3/22/20']
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 15960            NaN            Afghanistan  33.939110  67.709953  3/22/20
# 15961            NaN                Albania  41.153300  20.168300  3/22/20
# 15962            NaN                Algeria  28.033900   1.659600  3/22/20
# 15963            NaN                Andorra  42.506300   1.521800  3/22/20
# 15964            NaN                 Angola -11.202700  17.873900  3/22/20
# ...              ...                    ...        ...        ...      ...
# 16221            NaN  Sao Tome and Principe   0.186400   6.613100  3/22/20
# 16222            NaN                  Yemen  15.552727  48.516388  3/22/20
# 16223            NaN                Comoros -11.645500  43.333300  3/22/20
# 16224            NaN             Tajikistan  38.861000  71.276100  3/22/20
# 16225            NaN                Lesotho -29.610000  28.233600  3/22/20
#
#        Recovered
# 15960         40
# 15961         89
# ...
